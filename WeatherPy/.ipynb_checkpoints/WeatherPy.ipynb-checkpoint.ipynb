# %%
#!pip install citipy
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import citipy
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 586

# %%
weather_api_key = "66cf4bcae9c499b1f9df65136552db87"
weather_api_key
# Out:
# '66cf4bcae9c499b1f9df65136552db87'

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
units = "impirial"
query_url = url +"&units=" + units + "&q="

allcities = []
allcountries = []
clouds = []
dates = []
maxtemperature = []
wind = []
humidity = []
lat_list = []
lng_list = []

indexcount = 0
setcount = 1
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=66cf4bcae9c499b1f9df65136552db87'

# %%
print("Beginning Data Retrieval ")
print("-----------------------------")

for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(query_url + city).json()
        allcities.append(response["name"])
        clouds.append(response["clouds"]["all"])
        allcountries.append(response["sys"]["country"])
        dates.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        lat_list.append(response["coord"]["lat"])
        lng_list.append(response["coord"]["lon"])
        maxtemperature.append(response['main']['temp_max'])
        wind.append(response["wind"]["speed"])
        if indexcount > 49:
            indexcount = 0
            setcount = setcount + 1
    
        else:
            indexcount = indexcount + 1
            
        print(f"Processing Record {indexcount} of Set {setcount} : {city}") 
  
    except(KeyError, IndexError):
        print("City not found. Skipping...")

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 : harlingen
# Processing Record 2 of Set 1 : bredasdorp
# Processing Record 3 of Set 1 : tiksi
# Processing Record 4 of Set 1 : arraial do cabo
# Processing Record 5 of Set 1 : lebu
# Processing Record 6 of Set 1 : yellowknife
# Processing Record 7 of Set 1 : jamestown
# Processing Record 8 of Set 1 : pisco
# Processing Record 9 of Set 1 : rikitea
# Processing Record 10 of Set 1 : otane
# Processing Record 11 of Set 1 : kapaa
# Processing Record 12 of Set 1 : ulaangom
# Processing Record 13 of Set 1 : cidreira
# Processing Record 14 of Set 1 : broken hill
# Processing Record 15 of Set 1 : mujiayingzi
# City not found. Skipping...
# Processing Record 16 of Set 1 : provideniya
# Processing Record 17 of Set 1 : kaitangata
# Processing Record 18 of Set 1 : castro
# Processing Record 19 of Set 1 : sola
# City not found. Skipping...
# Processing Record 20 of Set 1 : ancud
# Processing Record 21 of Set 1 : ushuaia
# Processing Record 22 of Set 1 : kodiak
# Processing Record 23 of Set 1 : vaini
# Processing Record 24 of Set 1 : punta arenas
# City not found. Skipping...
# Processing Record 25 of Set 1 : saint-philippe
# Processing Record 26 of Set 1 : bandarbeyla
# Processing Record 27 of Set 1 : hermanus
# Processing Record 28 of Set 1 : hithadhoo
# Processing Record 29 of Set 1 : albany
# Processing Record 30 of Set 1 : port elizabeth
# Processing Record 31 of Set 1 : puerto ayora
# Processing Record 32 of Set 1 : torbay
# Processing Record 33 of Set 1 : shizuishan
# Processing Record 34 of Set 1 : san patricio
# Processing Record 35 of Set 1 : bosaso
# City not found. Skipping...
# Processing Record 36 of Set 1 : inhambane
# Processing Record 37 of Set 1 : guerrero negro
# Processing Record 38 of Set 1 : pevek
# Processing Record 39 of Set 1 : bethel
# Processing Record 40 of Set 1 : los andes
# Processing Record 41 of Set 1 : cape town
# Processing Record 42 of Set 1 : ribeira grande
# Processing Record 43 of Set 1 : mount isa
# Processing Record 44 of Set 1 : kloulklubed
# Processing Record 45 of Set 1 : longyearbyen
# Processing Record 46 of Set 1 : koutiala
# Processing Record 47 of Set 1 : georgetown
# Processing Record 48 of Set 1 : harrismith
# Processing Record 49 of Set 1 : voi
# Processing Record 50 of Set 1 : avarua
# Processing Record 0 of Set 2 : borba
# Processing Record 1 of Set 2 : coos bay
# Processing Record 2 of Set 2 : port alfred
# Processing Record 3 of Set 2 : asau
# City not found. Skipping...
# Processing Record 4 of Set 2 : cortes
# Processing Record 5 of Set 2 : nikolskoye
# Processing Record 50 of Set 4 : chabahar
# Processing Record 0 of Set 5 : saint-augustin
# Processing Record 1 of Set 5 : butaritari
# Processing Record 2 of Set 5 : tayoltita
# Processing Record 3 of Set 5 : nexo
# Processing Record 4 of Set 5 : aklavik
# Processing Record 5 of Set 5 : gravdal
# Processing Record 6 of Set 5 : paramonga
# Processing Record 7 of Set 5 : chokurdakh
# Processing Record 8 of Set 5 : naryan-mar
# Processing Record 9 of Set 5 : jiazi
# Processing Record 10 of Set 5 : hasaki
# Processing Record 11 of Set 5 : husavik
# Processing Record 12 of Set 5 : yulara
# Processing Record 13 of Set 5 : susehri
# Processing Record 14 of Set 5 : bichena
# City not found. Skipping...
# Processing Record 15 of Set 5 : souillac
# Processing Record 16 of Set 5 : sisimiut
# Processing Record 17 of Set 5 : gbadolite
# Processing Record 18 of Set 5 : clyde river
# Processing Record 19 of Set 5 : romanovo
# Processing Record 20 of Set 5 : fukue
# Processing Record 21 of Set 5 : mormugao
# City not found. Skipping...
# Processing Record 22 of Set 5 : tacuati
# Processing Record 23 of Set 5 : waihi beach
# Processing Record 24 of Set 5 : hofn
# Processing Record 25 of Set 5 : inongo
# Processing Record 26 of Set 5 : palmer
# Processing Record 27 of Set 5 : ahipara
# Processing Record 28 of Set 5 : pitimbu
# Processing Record 29 of Set 5 : hualmay
# Processing Record 30 of Set 5 : churapcha
# City not found. Skipping...
# Processing Record 31 of Set 5 : merauke
# Processing Record 32 of Set 5 : sistranda
# Processing Record 33 of Set 5 : te anau
# Processing Record 34 of Set 5 : sao felix do xingu
# Processing Record 35 of Set 5 : raudeberg
# Processing Record 36 of Set 5 : sanmenxia
# Processing Record 37 of Set 5 : evensk
# Processing Record 38 of Set 5 : half moon bay
# Processing Record 39 of Set 5 : alcaniz
# City not found. Skipping...
# Processing Record 40 of Set 5 : carbonear
# Processing Record 41 of Set 5 : chicama
# Processing Record 42 of Set 5 : kangaatsiaq
# Processing Record 43 of Set 5 : westport
# Processing Record 44 of Set 5 : college
# Processing Record 45 of Set 5 : kununurra
# Processing Record 46 of Set 5 : santa rosa
# Processing Record 47 of Set 5 : khatanga
# Processing Record 48 of Set 5 : manicaragua
# Processing Record 49 of Set 5 : guadalupe
# Processing Record 50 of Set 5 : bireun
# Processing Record 0 of Set 6 : upernavik
# Processing Record 1 of Set 6 : saint george
# Processing Record 2 of Set 6 : sioux lookout
# Processing Record 3 of Set 6 : nikolayevsk-na-amure
# Processing Record 4 of Set 6 : zapolyarnyy
# Processing Record 5 of Set 6 : san cristobal
# Processing Record 6 of Set 6 : dormidontovka
# Processing Record 7 of Set 6 : kidal
# Processing Record 8 of Set 6 : hohhot
# Processing Record 9 of Set 6 : pangnirtung
# Processing Record 10 of Set 6 : ust-kut
# Processing Record 11 of Set 6 : yola
# Processing Record 12 of Set 6 : enid
# Processing Record 13 of Set 6 : yangjiang
# City not found. Skipping...
# Processing Record 14 of Set 6 : mjolby
# Processing Record 15 of Set 6 : noumea
# Processing Record 16 of Set 6 : talnakh
# Processing Record 17 of Set 6 : cururupu
# City not found. Skipping...
# Processing Record 18 of Set 6 : lensk
# Processing Record 19 of Set 6 : debre tabor
# Processing Record 20 of Set 6 : geraldton
# Processing Record 21 of Set 6 : cayenne
# Processing Record 22 of Set 6 : lahat
# Processing Record 23 of Set 6 : sikonge
# Processing Record 24 of Set 6 : mecca
# Processing Record 25 of Set 6 : libreville
# Processing Record 26 of Set 6 : portland
# Processing Record 27 of Set 6 : christchurch
# Processing Record 28 of Set 6 : vao
# Processing Record 29 of Set 6 : kansanshi
# Processing Record 30 of Set 6 : alofi
# Processing Record 31 of Set 6 : pucara
# City not found. Skipping...
# Processing Record 32 of Set 6 : xai-xai
# Processing Record 33 of Set 6 : besikduzu
# Processing Record 34 of Set 6 : uhlove
# Processing Record 35 of Set 6 : mehamn
# Processing Record 36 of Set 6 : verkhnyaya inta
# Processing Record 37 of Set 6 : tomatlan
# Processing Record 38 of Set 6 : port hardy
# Processing Record 39 of Set 6 : kuminskiy
# Processing Record 40 of Set 6 : udachnyy
# Processing Record 41 of Set 6 : bambous virieux
# Processing Record 42 of Set 6 : koungheul
# Processing Record 43 of Set 6 : salinas
# Processing Record 44 of Set 6 : monrovia
# Processing Record 45 of Set 6 : lock haven
# Processing Record 46 of Set 6 : farafangana
# Processing Record 47 of Set 6 : brownwood
# Processing Record 48 of Set 6 : adrar
# City not found. Skipping...
# Processing Record 49 of Set 6 : sakakah
# Processing Record 50 of Set 6 : zatoka
# Processing Record 0 of Set 7 : isangel
# Processing Record 1 of Set 7 : lucea
# Processing Record 2 of Set 7 : umm lajj
# Processing Record 3 of Set 7 : changji
# City not found. Skipping...
# Processing Record 4 of Set 7 : tashla
# Processing Record 5 of Set 7 : abeche
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 6 of Set 7 : bucerias
# Processing Record 7 of Set 7 : zeya
# Processing Record 8 of Set 7 : formosa do rio preto
# Processing Record 9 of Set 7 : shache
# Processing Record 10 of Set 7 : baringo
# Processing Record 11 of Set 7 : arona
# Processing Record 12 of Set 7 : glazov
# Processing Record 13 of Set 7 : nanortalik
# Processing Record 14 of Set 7 : luanda
# Processing Record 15 of Set 7 : alanya
# Processing Record 16 of Set 7 : luoyang
# Processing Record 17 of Set 7 : fairbanks
# Processing Record 18 of Set 7 : villa nueva
# Processing Record 19 of Set 7 : borogontsy
# Processing Record 20 of Set 7 : derzhavinsk
# Processing Record 21 of Set 7 : dawson creek
# Processing Record 22 of Set 7 : berlevag
# Processing Record 23 of Set 7 : tabory
# Processing Record 24 of Set 7 : karratha
# Processing Record 25 of Set 7 : nelson bay
# Processing Record 26 of Set 7 : nikki
# Processing Record 27 of Set 7 : abnub
# Processing Record 28 of Set 7 : boda
# Processing Record 29 of Set 7 : itaituba
# Processing Record 30 of Set 7 : lorengau
# Processing Record 31 of Set 7 : trelleborg
# Processing Record 32 of Set 7 : praia da vitoria
# Processing Record 33 of Set 7 : khuzhir
# Processing Record 34 of Set 7 : mumford
# Processing Record 35 of Set 7 : dolni bousov
# City not found. Skipping...
# Processing Record 36 of Set 7 : sao joao da barra
# Processing Record 37 of Set 7 : tabuk
# Processing Record 38 of Set 7 : mareeba
# Processing Record 39 of Set 7 : narsaq
# Processing Record 40 of Set 7 : wufeng
# Processing Record 41 of Set 7 : kensington
# Processing Record 42 of Set 7 : gizo
# Processing Record 43 of Set 7 : sitka
# City not found. Skipping...
# Processing Record 44 of Set 7 : lashio
# Processing Record 45 of Set 7 : duluth
# Processing Record 46 of Set 7 : xuddur
# Processing Record 47 of Set 7 : onega
# Processing Record 48 of Set 7 : emmett
# Processing Record 49 of Set 7 : tezu
# Processing Record 50 of Set 7 : cocobeach
# Processing Record 0 of Set 8 : urumqi
# Processing Record 1 of Set 8 : cairns
# Processing Record 2 of Set 8 : abalak
# Processing Record 3 of Set 8 : lagoa
# Processing Record 4 of Set 8 : paita
# Processing Record 5 of Set 8 : eureka
# Processing Record 6 of Set 8 : saint-paul-les-dax
# Processing Record 7 of Set 8 : benemerito de las americas
# City not found. Skipping...
# Processing Record 8 of Set 8 : homer
# Processing Record 9 of Set 8 : kadoma
# Processing Record 10 of Set 8 : ambon
# City not found. Skipping...
# Processing Record 11 of Set 8 : iskateley
# Processing Record 12 of Set 8 : ormara
# Processing Record 13 of Set 8 : porto novo
# Processing Record 14 of Set 8 : darnah
# Processing Record 15 of Set 8 : pundaguitan
# Processing Record 16 of Set 8 : havre-saint-pierre
# Processing Record 17 of Set 8 : pyaozerskiy
# Processing Record 18 of Set 8 : dingle
# Processing Record 19 of Set 8 : yuzhno-kurilsk
# Processing Record 20 of Set 8 : rockport
# Processing Record 21 of Set 8 : jumla
# Processing Record 22 of Set 8 : mahajanga
# Processing Record 23 of Set 8 : mahibadhoo
# Processing Record 24 of Set 8 : swan river
# Processing Record 25 of Set 8 : kahului
# Processing Record 26 of Set 8 : fasa
# Processing Record 27 of Set 8 : pandaria
# Processing Record 28 of Set 8 : severo-kurilsk
# Processing Record 29 of Set 8 : leningradskiy
# Processing Record 30 of Set 8 : west wendover
# City not found. Skipping...
# Processing Record 31 of Set 8 : kishapu
# Processing Record 32 of Set 8 : zarya
# Processing Record 33 of Set 8 : andenes
# Processing Record 34 of Set 8 : mouila
# Processing Record 35 of Set 8 : santa fe
# Processing Record 36 of Set 8 : ortakoy
# Processing Record 37 of Set 8 : surt
# Processing Record 38 of Set 8 : ponta delgada
# Processing Record 39 of Set 8 : witu
# Processing Record 40 of Set 8 : belmonte
# Processing Record 41 of Set 8 : teknaf
# Processing Record 42 of Set 8 : santo domingo
# Processing Record 43 of Set 8 : kerrville
# Processing Record 44 of Set 8 : elizabeth city
# Processing Record 45 of Set 8 : samarai
# Processing Record 46 of Set 8 : rio claro
# Processing Record 47 of Set 8 : broome
# Processing Record 48 of Set 8 : sibolga
# City not found. Skipping...
# Processing Record 49 of Set 8 : tokur
# Processing Record 50 of Set 8 : sao gabriel da cachoeira
# Processing Record 0 of Set 9 : pedra branca
# Processing Record 1 of Set 9 : katherine
# City not found. Skipping...
# Processing Record 2 of Set 9 : abu dhabi
# Processing Record 3 of Set 9 : cabo san lucas
# Processing Record 4 of Set 9 : isla mujeres
# City not found. Skipping...
# Processing Record 5 of Set 9 : vardo
# Processing Record 6 of Set 9 : bulgan
# Processing Record 7 of Set 9 : kirakira
# Processing Record 8 of Set 9 : copiapo
# Processing Record 9 of Set 9 : aloleng
# Processing Record 10 of Set 9 : bahia blanca
# Processing Record 11 of Set 9 : parys
# Processing Record 12 of Set 9 : beloha
# Processing Record 13 of Set 9 : boende
# Processing Record 14 of Set 9 : azle
# Processing Record 15 of Set 9 : mulchen
# Processing Record 16 of Set 9 : preobrazheniye
# Processing Record 17 of Set 9 : tolaga bay
# Processing Record 18 of Set 9 : ulaanbaatar
# Processing Record 19 of Set 9 : jemnice
# Processing Record 20 of Set 9 : qui nhon
# Processing Record 21 of Set 9 : de aar
# Processing Record 22 of Set 9 : bilibino
# City not found. Skipping...
# Processing Record 23 of Set 9 : micheweni
# Processing Record 24 of Set 9 : avera
# Processing Record 25 of Set 9 : abha
# Processing Record 26 of Set 9 : hami
# Processing Record 27 of Set 9 : ayan
# Processing Record 28 of Set 9 : yozgat
# Processing Record 29 of Set 9 : fort saint james
# Processing Record 30 of Set 9 : syracuse
# Processing Record 31 of Set 9 : kurilsk
# Processing Record 32 of Set 9 : waddan
# Processing Record 33 of Set 9 : martapura
# Processing Record 34 of Set 9 : bowen
# Processing Record 35 of Set 9 : oksfjord
# Processing Record 36 of Set 9 : cabrera
# Processing Record 37 of Set 9 : hirara
# Processing Record 38 of Set 9 : fortuna
# Processing Record 39 of Set 9 : fort frances
# Processing Record 40 of Set 9 : muravlenko
# Processing Record 41 of Set 9 : kavieng
# Processing Record 42 of Set 9 : fort nelson
# Processing Record 43 of Set 9 : anuradhapura
# Processing Record 44 of Set 9 : igbaras
# Processing Record 45 of Set 9 : ilinskiy
# Processing Record 46 of Set 9 : itoman
# Processing Record 47 of Set 9 : tuatapere
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     725
# --> 726             retries = retries.increment(
#     727                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~\anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     409             if read is False or not self._is_method_retryable(method):
# --> 410                 raise six.reraise(type(error), error, _stacktrace)
#     411             elif read is not None:
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     733             if value.__traceback__ is not tb:
# --> 734                 raise value.with_traceback(tb)
#     735             raise value
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-5-aed13b458d4d> in <module>
#       4 for index, city in enumerate(cities, start = 1):
#       5     try:
# ----> 6         response = requests.get(query_url + city).json()
#       7         allcities.append(response["name"])
#       8         clouds.append(response["clouds"]["all"])
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))

# %%
#make DF
weatherDF = pd.DataFrame({ "City" : allcities,"Lat" : lat_list,"Lng" : lng_list,"Max Temp" : maxtemperature,
                          "Humidity" : humidity, "Cloudiness" : clouds,"Wind Speed" : wind, 
                          "Country" : allcountries,"Date" : dates})
weatherDF.head()

# %%
#LAT VS TEMP
plt.scatter(weatherDF["Lat"], weatherDF["Max Temp"], color = "steelblue")
plt.title("City Latitude vs. Max Temperature (04/01/20)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# %%
#LAT VS HUMIDITY
plt.scatter(weatherDF["Lat"], weatherDF["Humidity"], color = "steelblue")
plt.title("City Latitude vs. Humidity (04/01/20)")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# %%
#LAT VS HUMIDITY
plt.scatter(weatherDF["Lat"], weatherDF["Humidity"], color = "steelblue")
plt.title("City Latitude vs. Humidity (04/01/20)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# %%
#LAT VS CLOUDINESS
plt.scatter(weatherDF["Lat"], weatherDF["Cloudiness"], color = "steelblue")
plt.title("City Latitude vs. Cloudiness (04/01/20)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# %%
#LAT VS WIND SPEED
plt.scatter(weatherDF["Lat"], weatherDF["Wind Speed"], color = "steelblue")
plt.title("City Latitude vs. Wind Speed (04/01/20)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# %%
#----------------------REGRESSIONS-------------------------

# %%
#Northern Hemisphere - Max Temp vs. Latitude Linear Regression
from scipy import stats
x_values = northhemi['Max Temp']
y_values = northhemi['Lat']

def linearregression(x,y):
    print(f"The r-squared is : {rvalue} ")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regvalues = x * slope + intercept
    equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regvalues,"r-")
    return equation
def annotate(equation, a, b):
    plt.annotate(equation,(a,b),fontsize=15,color="red")

# %%
#make dataframes with .loc for each hemisphere
northhemi = weatherDF.loc[weatherDF["Lat"] >= 0]
southhemi = weatherDF.loc[weatherDF["Lat"] < 0]

#(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# %%
southhemi

# %%
equation = linearregression(northhemi["Lat"], northhemi["Max Temp"])
annotate(equation, 0, 0)
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
