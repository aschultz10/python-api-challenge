# %%
# !pip install citipy
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import citipy
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
# Out:
# Collecting citipy
#   Using cached citipy-0.0.5.tar.gz (557 kB)
# Collecting kdtree>=0.12
#   Using cached kdtree-0.16-py2.py3-none-any.whl (7.7 kB)
# Building wheels for collected packages: citipy
#   Building wheel for citipy (setup.py): started
#   Building wheel for citipy (setup.py): finished with status 'done'
#   Created wheel for citipy: filename=citipy-0.0.5-py3-none-any.whl size=559704 sha256=d84a9aae4878bd556ebdc1a6086ddbaca7cdba93096c2e28507c0d13901e5808
#   Stored in directory: c:\users\alexe\appdata\local\pip\cache\wheels\72\ae\63\5d03cf6dfe5c0e9328fb73f8b30da1948a06b9cceaf2c68d2d
# Successfully built citipy
# Installing collected packages: kdtree, citipy
# Successfully installed citipy-0.0.5 kdtree-0.16

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 618

# %%
weather_api_key = "66cf4bcae9c499b1f9df65136552db87"
weather_api_key
# Out:
# '66cf4bcae9c499b1f9df65136552db87'

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
units = "impirial"
query_url = url +"&units=" + units + "&q="

allcities = []
allcountries = []
clouds = []
dates = []
maxtemperature = []
wind = []
humidity = []
lat_list = []
lng_list = []

indexcount = 0
setcount = 1
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=66cf4bcae9c499b1f9df65136552db87'

# %%
print("Beginning Data Retrieval ")
print("-----------------------------")

for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(query_url + city).json()
        allcities.append(response["name"])
        clouds.append(response["clouds"]["all"])
        allcountries.append(response["sys"]["country"])
        dates.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        lat_list.append(response["coord"]["lat"])
        lng_list.append(response["coord"]["lon"])
        maxtemperature.append(response['main']['temp_max'])
        wind.append(response["wind"]["speed"])
        if indexcount > 49:
            indexcount = 0
            setcount = setcount + 1
    
        else:
            indexcount = indexcount + 1
            
        print(f"Processing Record {indexcount} of Set {setcount} : {city}") 
  
    except(KeyError, IndexError):
        print("City not found. Skipping...")

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 : tarbagatay
# Processing Record 2 of Set 1 : bambous virieux
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 3 of Set 1 : yumen
# Processing Record 4 of Set 1 : port alfred
# Processing Record 5 of Set 1 : palauig
# Processing Record 6 of Set 1 : puerto ayora
# Processing Record 7 of Set 1 : mataura
# Processing Record 8 of Set 1 : barrow
# Processing Record 9 of Set 1 : hilo
# Processing Record 10 of Set 1 : jamestown
# Processing Record 11 of Set 1 : punta arenas
# Processing Record 12 of Set 1 : yellowknife
# Processing Record 13 of Set 1 : avarua
# Processing Record 14 of Set 1 : tombouctou
# Processing Record 15 of Set 1 : necochea
# Processing Record 16 of Set 1 : bengkulu
# Processing Record 17 of Set 1 : bluff
# Processing Record 18 of Set 1 : thompson
# Processing Record 19 of Set 1 : atuona
# Processing Record 20 of Set 1 : seoul
# Processing Record 21 of Set 1 : ushuaia
# Processing Record 22 of Set 1 : qaanaaq
# Processing Record 23 of Set 1 : mount gambier
# Processing Record 24 of Set 1 : lawton
# Processing Record 25 of Set 1 : avera
# Processing Record 26 of Set 1 : khatanga
# Processing Record 27 of Set 1 : dukat
# Processing Record 28 of Set 1 : rikitea
# Processing Record 29 of Set 1 : carnarvon
# Processing Record 30 of Set 1 : najran
# Processing Record 31 of Set 1 : mahebourg
# Processing Record 32 of Set 1 : tazmalt
# Processing Record 33 of Set 1 : svetlaya
# Processing Record 34 of Set 1 : auki
# Processing Record 35 of Set 1 : havoysund
# Processing Record 36 of Set 1 : cape town
# Processing Record 37 of Set 1 : vanimo
# Processing Record 38 of Set 1 : norman wells
# Processing Record 39 of Set 1 : kapaa
# City not found. Skipping...
# Processing Record 40 of Set 1 : new norfolk
# City not found. Skipping...
# Processing Record 41 of Set 1 : sola
# Processing Record 42 of Set 1 : chokurdakh
# Processing Record 43 of Set 1 : wembley
# Processing Record 44 of Set 1 : castro
# Processing Record 45 of Set 1 : sol-iletsk
# Processing Record 46 of Set 1 : irshava
# Processing Record 47 of Set 1 : itajobi
# Processing Record 48 of Set 1 : peniche
# Processing Record 49 of Set 1 : hualmay
# Processing Record 50 of Set 1 : shingu
# City not found. Skipping...
# Processing Record 0 of Set 2 : lagoa
# Processing Record 1 of Set 2 : olafsvik
# Processing Record 2 of Set 2 : kars
# Processing Record 3 of Set 2 : leningradskiy
# Processing Record 4 of Set 2 : batagay
# Processing Record 5 of Set 2 : shaowu
# Processing Record 6 of Set 2 : kodiak
# Processing Record 7 of Set 2 : morant bay
# City not found. Skipping...
# Processing Record 8 of Set 2 : tasiilaq
# Processing Record 9 of Set 2 : codrington
# Processing Record 10 of Set 2 : the valley
# Processing Record 11 of Set 2 : bilma
# Processing Record 12 of Set 2 : tuatapere
# Processing Record 13 of Set 2 : sorland
# Processing Record 14 of Set 2 : dok kham tai
# Processing Record 15 of Set 2 : komsomolskiy
# City not found. Skipping...
# Processing Record 16 of Set 2 : la asuncion
# Processing Record 17 of Set 2 : mackay
# Processing Record 18 of Set 2 : airai
# Processing Record 19 of Set 2 : busselton
# Processing Record 20 of Set 2 : langxiang
# Processing Record 21 of Set 2 : college
# Processing Record 22 of Set 2 : tianpeng
# Processing Record 23 of Set 2 : cherskiy
# Processing Record 24 of Set 2 : lebu
# Processing Record 25 of Set 2 : kysyl-syr
# City not found. Skipping...
# Processing Record 26 of Set 2 : ostrovnoy
# Processing Record 27 of Set 2 : bay roberts
# Processing Record 28 of Set 2 : karatau
# Processing Record 29 of Set 2 : saint-georges
# Processing Record 30 of Set 2 : vaini
# Processing Record 31 of Set 2 : hereford
# Processing Record 32 of Set 2 : kavieng
# Processing Record 33 of Set 2 : longyearbyen
# Processing Record 34 of Set 2 : fairbanks
# City not found. Skipping...
# Processing Record 35 of Set 2 : yar-sale
# Processing Record 36 of Set 2 : georgetown
# Processing Record 37 of Set 2 : bredasdorp
# Processing Record 38 of Set 2 : husavik
# Processing Record 39 of Set 2 : marawi
# Processing Record 40 of Set 2 : sobolevo
# Processing Record 41 of Set 2 : sisimiut
# Processing Record 42 of Set 2 : malakwal
# Processing Record 43 of Set 2 : ilulissat
# Processing Record 44 of Set 2 : albany
# Processing Record 45 of Set 2 : muswellbrook
# Processing Record 46 of Set 2 : port elizabeth
# City not found. Skipping...
# Processing Record 47 of Set 2 : ginda
# Processing Record 48 of Set 2 : zinder
# Processing Record 49 of Set 2 : saskylakh
# Processing Record 50 of Set 2 : raudeberg
# Processing Record 0 of Set 3 : klaksvik
# Processing Record 1 of Set 3 : abhaynagar
# Processing Record 2 of Set 3 : kamenka
# City not found. Skipping...
# Processing Record 3 of Set 3 : zalantun
# Processing Record 4 of Set 3 : bethel
# Processing Record 5 of Set 3 : lasa
# Processing Record 6 of Set 3 : teya
# Processing Record 7 of Set 3 : weihe
# Processing Record 8 of Set 3 : saint-francois
# City not found. Skipping...
# Processing Record 9 of Set 3 : hamilton
# Processing Record 10 of Set 3 : tongliao
# Processing Record 11 of Set 3 : magadan
# Processing Record 12 of Set 3 : kimberley
# Processing Record 13 of Set 3 : teknaf
# City not found. Skipping...
# Processing Record 14 of Set 3 : mursalimkino
iy
# City not found. Skipping...
# Processing Record 31 of Set 4 : ambovombe
# Processing Record 32 of Set 4 : south sioux city
# Processing Record 33 of Set 4 : sao filipe
# Processing Record 34 of Set 4 : adrar
# Processing Record 35 of Set 4 : pevek
# Processing Record 36 of Set 4 : makakilo city
# Processing Record 37 of Set 4 : araouane
# Processing Record 38 of Set 4 : ponta delgada
# Processing Record 39 of Set 4 : monroe
# Processing Record 40 of Set 4 : torbay
# Processing Record 41 of Set 4 : tucuma
# Processing Record 42 of Set 4 : pitelino
# Processing Record 43 of Set 4 : borogontsy
# Processing Record 44 of Set 4 : teruel
# Processing Record 45 of Set 4 : harrai
# Processing Record 46 of Set 4 : petropavlovsk-kamchatskiy
# City not found. Skipping...
# Processing Record 47 of Set 4 : khotyn
# Processing Record 48 of Set 4 : ketchikan
# Processing Record 49 of Set 4 : haines junction
# Processing Record 50 of Set 4 : moba
# Processing Record 0 of Set 5 : taoudenni
# Processing Record 1 of Set 5 : chuy
# Processing Record 2 of Set 5 : nome
# Processing Record 3 of Set 5 : shahr-e babak
# Processing Record 4 of Set 5 : muhlhausen
# Processing Record 5 of Set 5 : banes
# Processing Record 6 of Set 5 : hervey bay
# Processing Record 7 of Set 5 : vila velha
# Processing Record 8 of Set 5 : vardo
# Processing Record 9 of Set 5 : sungaipenuh
# Processing Record 10 of Set 5 : luderitz
# Processing Record 11 of Set 5 : adiake
# Processing Record 12 of Set 5 : tuktoyaktuk
# City not found. Skipping...
# Processing Record 13 of Set 5 : dunedin
# Processing Record 14 of Set 5 : kargil
# Processing Record 15 of Set 5 : arman
# Processing Record 16 of Set 5 : griffith
# Processing Record 17 of Set 5 : abu dhabi
# Processing Record 18 of Set 5 : jiuquan
# Processing Record 19 of Set 5 : comodoro rivadavia
# Processing Record 20 of Set 5 : banda aceh
# Processing Record 21 of Set 5 : babushkin
# Processing Record 22 of Set 5 : marovoay
# Processing Record 23 of Set 5 : astara
# City not found. Skipping...
# Processing Record 24 of Set 5 : huambo
# Processing Record 25 of Set 5 : mayo
# Processing Record 26 of Set 5 : dekar
# Processing Record 27 of Set 5 : baykit
# Processing Record 28 of Set 5 : maragogi
# Processing Record 29 of Set 5 : yabelo
# Processing Record 30 of Set 5 : saint-louis
# Processing Record 31 of Set 5 : cascas
# Processing Record 32 of Set 5 : cidreira
# Processing Record 33 of Set 5 : khasan
# Processing Record 34 of Set 5 : tuy hoa
# City not found. Skipping...
# Processing Record 35 of Set 5 : flin flon
# Processing Record 36 of Set 5 : uusikaupunki
# Processing Record 37 of Set 5 : cabo san lucas
# Processing Record 38 of Set 5 : faanui
# Processing Record 39 of Set 5 : chapais
# Processing Record 40 of Set 5 : flinders
# Processing Record 41 of Set 5 : kendari
# Processing Record 42 of Set 5 : asyut
# City not found. Skipping...
# Processing Record 43 of Set 5 : pinkafeld
# Processing Record 44 of Set 5 : hambantota
# Processing Record 45 of Set 5 : vestmanna
# Processing Record 46 of Set 5 : iturama
# City not found. Skipping...
# Processing Record 47 of Set 5 : geraldton
# Processing Record 48 of Set 5 : hermiston
# Processing Record 49 of Set 5 : lokosovo
# Processing Record 50 of Set 5 : kremenki
# Processing Record 0 of Set 6 : boende
# Processing Record 1 of Set 6 : pisco
# Processing Record 2 of Set 6 : goderich
# Processing Record 3 of Set 6 : elko
# Processing Record 4 of Set 6 : khandyga
# City not found. Skipping...
# Processing Record 5 of Set 6 : buluang
# Processing Record 6 of Set 6 : orlik
# Processing Record 7 of Set 6 : rio gallegos
# Processing Record 8 of Set 6 : alofi
# Processing Record 9 of Set 6 : barbalha
# Processing Record 10 of Set 6 : yotoco
# Processing Record 11 of Set 6 : vestmannaeyjar
# Processing Record 12 of Set 6 : veraval
# Processing Record 13 of Set 6 : rocha
# Processing Record 14 of Set 6 : verkh-usugli
# Processing Record 15 of Set 6 : morrisburg
# City not found. Skipping...
# Processing Record 16 of Set 6 : miraflores
# Processing Record 17 of Set 6 : belyy yar
# Processing Record 18 of Set 6 : kurchum
# Processing Record 19 of Set 6 : karasuk
# Processing Record 20 of Set 6 : san policarpo
# Processing Record 21 of Set 6 : hami
# Processing Record 22 of Set 6 : upernavik
# Processing Record 23 of Set 6 : berlevag
# Processing Record 24 of Set 6 : margate
# Processing Record 25 of Set 6 : north bend
# Processing Record 26 of Set 6 : merauke
# Processing Record 27 of Set 6 : boda
# Processing Record 28 of Set 6 : batagay-alyta
# Processing Record 29 of Set 6 : joshimath
# Processing Record 30 of Set 6 : agua branca
# Processing Record 31 of Set 6 : bayan
# Processing Record 32 of Set 6 : guozhen
# Processing Record 33 of Set 6 : steti
# Processing Record 34 of Set 6 : aden
# City not found. Skipping...
# Processing Record 35 of Set 6 : dataganj
# Processing Record 36 of Set 6 : provideniya
# Processing Record 37 of Set 6 : santa marta
# Processing Record 38 of Set 6 : aykhal
# City not found. Skipping...
# Processing Record 39 of Set 6 : okha
# Processing Record 40 of Set 6 : sunbury
# Processing Record 41 of Set 6 : yahotyn
# Processing Record 42 of Set 6 : sipe sipe
# Processing Record 43 of Set 6 : hobyo
# City not found. Skipping...
# Processing Record 44 of Set 6 : meulaboh
# Processing Record 45 of Set 6 : jinchang
# Processing Record 46 of Set 6 : rio grande
# Processing Record 47 of Set 6 : hithadhoo
# Processing Record 48 of Set 6 : iranshahr
# City not found. Skipping...
# Processing Record 49 of Set 6 : kashi
# Processing Record 50 of Set 6 : dayong
# Processing Record 0 of Set 7 : zambezi
# Processing Record 1 of Set 7 : balkanabat
# Processing Record 2 of Set 7 : anadyr
# Processing Record 3 of Set 7 : srednekolymsk
# Processing Record 4 of Set 7 : saint anthony
# Processing Record 5 of Set 7 : luena
# Processing Record 6 of Set 7 : terrak
# Processing Record 7 of Set 7 : atar
# Processing Record 8 of Set 7 : hvide sande
# Processing Record 9 of Set 7 : el tigre
# Processing Record 10 of Set 7 : dunmore town
# Processing Record 11 of Set 7 : dryden
# Processing Record 12 of Set 7 : fort nelson
# Processing Record 13 of Set 7 : ribeira grande
# Processing Record 14 of Set 7 : caravelas
# Processing Record 15 of Set 7 : inverell
# Processing Record 16 of Set 7 : yulara
# Processing Record 9 of Set 10 : balabac
# City not found. Skipping...
# Processing Record 10 of Set 10 : roma
# Processing Record 11 of Set 10 : rapid valley
# Processing Record 12 of Set 10 : mantua
# Processing Record 13 of Set 10 : brae
# Processing Record 14 of Set 10 : pacific grove
# Processing Record 15 of Set 10 : lethem
# Processing Record 16 of Set 10 : maymyo
# Processing Record 17 of Set 10 : chunoyar
# Processing Record 18 of Set 10 : mabaruma
# Processing Record 19 of Set 10 : clyde river
# Processing Record 20 of Set 10 : ivybridge
# City not found. Skipping...
# Processing Record 21 of Set 10 : carballo
# City not found. Skipping...
# Processing Record 22 of Set 10 : lar
# Processing Record 23 of Set 10 : alta floresta
# Processing Record 24 of Set 10 : oriximina
# Processing Record 25 of Set 10 : touros
# Processing Record 26 of Set 10 : omboue
# Processing Record 27 of Set 10 : nikel
# Processing Record 28 of Set 10 : deer lake
# Processing Record 29 of Set 10 : asau
# Processing Record 30 of Set 10 : edwardsville
# Processing Record 31 of Set 10 : itanhaem
# Processing Record 32 of Set 10 : calabozo
# Processing Record 33 of Set 10 : linxia
# Processing Record 34 of Set 10 : zyryanka
# Processing Record 35 of Set 10 : esterhazy
# Processing Record 36 of Set 10 : wahpeton
# Processing Record 37 of Set 10 : hope
# Processing Record 38 of Set 10 : newport
# Processing Record 39 of Set 10 : phan thiet
# Processing Record 40 of Set 10 : birin
# Processing Record 41 of Set 10 : ulundi
# Processing Record 42 of Set 10 : dumai
# Processing Record 43 of Set 10 : wewak
# Processing Record 44 of Set 10 : fernley
# Processing Record 45 of Set 10 : shambu
# Processing Record 46 of Set 10 : russkaya polyana
# Processing Record 47 of Set 10 : quatre cocos
# Processing Record 48 of Set 10 : aquiraz
# Processing Record 49 of Set 10 : port augusta
# Processing Record 50 of Set 10 : vladimiro-aleksandrovskoye
# Processing Record 0 of Set 11 : astorga
# Processing Record 1 of Set 11 : abu kamal
# Processing Record 2 of Set 11 : lake havasu city
# Processing Record 3 of Set 11 : oussouye
# Processing Record 4 of Set 11 : awbari
# Processing Record 5 of Set 11 : darnah
# Processing Record 6 of Set 11 : san ciro de acosta
# Processing Record 7 of Set 11 : pangnirtung
# City not found. Skipping...
# Processing Record 8 of Set 11 : beloha
# Processing Record 9 of Set 11 : nha trang
# Processing Record 10 of Set 11 : turukhansk
# Processing Record 11 of Set 11 : povenets
# Processing Record 12 of Set 11 : alice springs
# Processing Record 13 of Set 11 : sechura
# Processing Record 14 of Set 11 : praia da vitoria
# Processing Record 15 of Set 11 : menongue
# Processing Record 16 of Set 11 : havre
# Processing Record 17 of Set 11 : bani
# Processing Record 18 of Set 11 : grand gaube
# Processing Record 19 of Set 11 : pitsunda
# Processing Record 20 of Set 11 : tautira
# Processing Record 21 of Set 11 : sabinas hidalgo
# Processing Record 22 of Set 11 : kununurra
# Processing Record 23 of Set 11 : chauk
# Processing Record 24 of Set 11 : ippy
# Processing Record 25 of Set 11 : machalpur
# Processing Record 26 of Set 11 : ruiselede
# Processing Record 27 of Set 11 : manokwari
# Processing Record 28 of Set 11 : severnoye
# Processing Record 29 of Set 11 : filingue
# Processing Record 30 of Set 11 : ahipara
# Processing Record 31 of Set 11 : general roca
# Processing Record 32 of Set 11 : enshi
# Processing Record 33 of Set 11 : ust-kuyga
# Processing Record 34 of Set 11 : viedma
# Processing Record 35 of Set 11 : soyo
# Processing Record 36 of Set 11 : san andres
# Processing Record 37 of Set 11 : chipinge
# Processing Record 38 of Set 11 : lompoc
# City not found. Skipping...
# Processing Record 39 of Set 11 : ligayan
# Processing Record 40 of Set 11 : ugep
# Processing Record 41 of Set 11 : matagami
# Processing Record 42 of Set 11 : cururupu
# Processing Record 43 of Set 11 : kadnikov
# Processing Record 44 of Set 11 : hsinchu
# Processing Record 45 of Set 11 : virginia beach
# Processing Record 46 of Set 11 : linhares
# Processing Record 47 of Set 11 : coihaique
# Processing Record 48 of Set 11 : klenovyy
# Processing Record 49 of Set 11 : kontagora
# Processing Record 50 of Set 11 : tazovskiy
# Processing Record 0 of Set 12 : port lincoln
# Processing Record 1 of Set 12 : maturin
# Processing Record 2 of Set 12 : naples
# Processing Record 3 of Set 12 : helong
# Processing Record 4 of Set 12 : kathu
# Processing Record 5 of Set 12 : derzhavinsk
# Processing Record 6 of Set 12 : kudahuvadhoo
# Processing Record 7 of Set 12 : capreol
# Processing Record 8 of Set 12 : santiago del estero
# Processing Record 9 of Set 12 : kigoma
# Processing Record 10 of Set 12 : mudgee
# Processing Record 11 of Set 12 : san fernando
# Processing Record 12 of Set 12 : kjollefjord
# Processing Record 13 of Set 12 : curuguaty
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#make DF
weatherDF = pd.DataFrame({ "City" : allcities,"Lat" : lat_list,"Lng" : lng_list,"Max Temp" : maxtemperature,
                          "Humidity" : humidity, "Cloudiness" : clouds,"Wind Speed" : wind, 
                          "Country" : allcountries,"Date" : dates})
weatherDF.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Tarbagatay  51.4803  107.3602     -0.40        85          29
# 1  Bambous Virieux -20.3428   57.7575     82.00        78          75
# 2            Yumen  40.2833   97.2000     32.05        79          16
# 3      Port Alfred -33.5906   26.8910     68.00        91           0
# 4          Palauig  15.4350  119.9045     77.31        69           1
#
#    Wind Speed Country        Date
# 0        1.74      RU  1615060759
# 1        8.05      MU  1615060759
# 2        1.90      CN  1615060760
# 3        1.99      ZA  1615060761
# 4        5.88      PH  1615060761

# %%
#LAT VS TEMP
plt.scatter(weatherDF["Lat"], weatherDF["Max Temp"], color = "steelblue")
plt.title("City Latitude vs. Max Temperature (04/01/20)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# %%
#LAT VS HUMIDITY
plt.scatter(weatherDF["Lat"], weatherDF["Humidity"], color = "steelblue")
plt.title("City Latitude vs. Humidity (04/01/20)")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# %%
#LAT VS HUMIDITY
plt.scatter(weatherDF["Lat"], weatherDF["Humidity"], color = "steelblue")
plt.title("City Latitude vs. Humidity (04/01/20)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# %%
#LAT VS CLOUDINESS
plt.scatter(weatherDF["Lat"], weatherDF["Cloudiness"], color = "steelblue")
plt.title("City Latitude vs. Cloudiness (04/01/20)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# %%
#LAT VS WIND SPEED
plt.scatter(weatherDF["Lat"], weatherDF["Wind Speed"], color = "steelblue")
plt.title("City Latitude vs. Wind Speed (04/01/20)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# %%
#----------------------REGRESSIONS-------------------------#

# %%
#Northern Hemisphere - Max Temp vs. Latitude Linear Regression
from scipy import stats

def linearregression(x,y):
    print(f"The r-squared is :  ")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regvalues = x * slope + intercept
    equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regvalues,"r-")
    return equation
def annotate(equation, a, b):
    plt.annotate(equation,(a,b),fontsize=15,color="red")

# %%
#make dataframes with .loc for each hemisphere
northhemi = weatherDF.loc[weatherDF["Lat"] >= 0]
southhemi = weatherDF.loc[weatherDF["Lat"] < 0]
x_values = northhemi['Max Temp']
y_values = northhemi['Lat']

#(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# %%
southhemi
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 1        Bambous Virieux -20.3428   57.7575     82.00        78          75
# 3            Port Alfred -33.5906   26.8910     68.00        91           0
# 5           Puerto Ayora  -0.7393  -90.3518     80.60        83          75
# 6                Mataura -46.1927  168.8643     48.00        93          23
# 10          Punta Arenas -53.1500  -70.9167     57.20        38           0
# ..                   ...      ...       ...       ...       ...         ...
# 560         Port Lincoln -34.7333  135.8667     63.05        83         100
# 568  Santiago del Estero -27.7951  -64.2615     94.08        25           0
# 569               Kigoma  -4.8769   29.6267     73.40        88          75
# 570               Mudgee -32.5943  149.5871     57.99        82           8
# 573            Curuguaty -24.4694  -55.6945     85.37        51          54
#
#      Wind Speed Country        Date
# 1          8.05      MU  1615060759
# 3          1.99      ZA  1615060761
# 5          5.75      EC  1615060761
# 6          5.01      NZ  1615060761
# 10        41.43      CL  1615060762
# ..          ...     ...         ...
# 560        6.82      AU  1615060878
# 568        5.61      AR  1615060880
# 569        1.92      TZ  1615060880
# 570        4.61      AU  1615060880
# 573        6.13      PY  1615060881
#
# [172 rows x 9 columns]

# %%
#Northern Hemisphere - Temperature (F) vs. Latitude

equation = linearregression(northhemi["Lat"], northhemi["Max Temp"])
annotate(equation, 0, 0)
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
# Out:
# The r-squared is :
# Text(0, 0.5, 'Max Temp (F)')

# %%
#Southern Hemisphere - Temperature (F) vs. Latitude

equation = linearregression(southhemi["Lat"], southhemi["Max Temp"])
annotate(equation, 0, 0)
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
# Out:
# The r-squared is :
# Text(0, 0.5, 'Max Temp (F)')

# %%
#Northern Hemisphere - Humidity (%) vs. Latitude

equation = linearregression(northhemi["Lat"], northhemi["Humidity"])
annotate(equation, 0, 0)
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
# Out:
# The r-squared is :
# Text(0, 0.5, 'Humidity (%)')

# %%
#Southern Hemisphere - Humidity (%) vs. Latitude
equation = linearregression(southhemi["Lat"], southhemi["Humidity"])
annotate(equation, 0, 0)
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
# Out:
# The r-squared is :
# Text(0, 0.5, 'Humidity (%)')

# %%
#Northern Hemisphere - Cloudiness (%) vs. Latitude
equation = linearregression(northhemi["Lat"], northhemi["Cloudiness"])
annotate(equation, 0, 0)
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
# Out:
# The r-squared is :
# Text(0, 0.5, 'Cloudiness (%)')

# %%
#Southern Hemisphere - Cloudiness (%) vs. Latitude

equation = linearregression(southhemi["Lat"], southhemi["Cloudiness"])
annotate(equation, 0, 0)
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
# Out:
# The r-squared is :
# Text(0, 0.5, 'Cloudiness (%)')

# %%
#Northern Hemisphere - Wind Speed (mph) vs. Latitude

equation = linearregression(northhemi["Lat"], northhemi["Cloudiness"])
annotate(equation, 0, 0)
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
# Out:
# The r-squared is :
# Text(0, 0.5, 'Wind Speed (mph)')

# %%
#Southern Hemisphere - Wind Speed (mph) vs. Latitude

equation = linearregression(southhemi["Lat"], southhemi["Cloudiness"])
annotate(equation, 0, 0)
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
# Out:
# The r-squared is :
# Text(0, 0.5, 'Wind Speed (mph)')

# %% [markdown]
# Observations:
# 1) Wind speed does not seem to be correlated with latitude, for the data is very scattered and I cannot find a clear relationship. There seems to be slightly more data correlation between high wind MPH and high latitude but not enough to establish a relationship.
#
# 2) There is less variation in max temperature in the Southern Hemisphere which I found interesting. Possibly this is due to the fact that there is much more ocean instead of land, which could cause less variation. The max temperatures in the Northern Hemisphere could have more variation due to the land masses in higher latitudes. Examples include Russia, Greenland, and Canada.
#
# 3) The majority of the world faces similar wind speeds which is probably why there is not a lot of correlation between wind speed and latitude. Cloudiness is somewhat similar, although the distribution is a little more scattered, probably another reason I could not find much correlation with cloudiness and latitude. It is interesting though how it seems like a large chunk of cities are above the 70% cloudiness level at higher latitudes in the Northern Hemisphere.
